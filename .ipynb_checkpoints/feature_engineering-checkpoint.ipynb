# %%
# %run ./setting.ipynb

# %%
qqq = pd.read_parquet(
    os.path.join(
    data_path,
    "qqq.parquet")
)

# %%
qqq.to_sql(
    "qqq", 
    conn,
    if_exists = "replace",
    )
# Out:
# 6095

# %%
columns_value = {
"Open":["max", "avg", "min"],
"Close":["max", "avg", "min"],
"Volume":["max", "avg", "min"],
}

# %%
sql(f"""
select *, 
Close/Open as ratio,
Close - Open as increase
from qqq
limit 10;
""")
# Out:
#    index                       Date       Open       High        Low
# 0      0  1999-03-10 00:00:00-05:00  43.892056  43.918885  43.167676  \
# 1      1  1999-03-11 00:00:00-05:00  44.160325  44.415199  43.194485
# 2      2  1999-03-12 00:00:00-05:00  43.892040  43.918869  42.631083
# 3      3  1999-03-15 00:00:00-05:00  43.301822  44.267662  42.845731
# 4      4  1999-03-16 00:00:00-05:00  44.401801  44.777406  43.918881
# 5      5  1999-03-17 00:00:00-05:00  44.589601  44.643259  44.133510
# 6      6  1999-03-18 00:00:00-05:00  44.213997  45.153008  44.200582
# 7      7  1999-03-19 00:00:00-05:00  45.716419  45.716419  43.945713
# 8      8  1999-03-22 00:00:00-05:00  44.160339  44.267654  43.355472
# 9      9  1999-03-23 00:00:00-05:00  43.194490  43.355463  41.826217
#
#        Close    Volume  Dividends  Stock Splits  Capital Gains     ratio
# 0  43.838398   5232000        0.0           0.0            0.0  0.998778  \
# ...
